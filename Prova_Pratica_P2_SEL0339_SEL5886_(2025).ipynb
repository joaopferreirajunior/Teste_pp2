# %% [markdown]
# # Prova prática 2 - SEL0339/SEL5886 (2025)
# ### Introdução à Visão Computacional (SEL0339/SEL5886)
#
# **Instruções:**
#
#  1. Esta prova consiste em 3 exercícios.
#  1. Deve-se colocar comentários nos códigos desenvolvidos.
#
#
# ATENÇÃO!
#
# Leia atentamente as instruções antes de iniciar a prova.
#
# Não serão aceitas reclamações posteriores por desconhecimento de qualquer informação descrita neste tópico.
#
#
#
# **Instruções para a realização da Prova 2 prática de Introdução à Visão Computacional (SEL0339/SEL5886):**
#
# - A prova PP2 estará disponível no sistema e-Disciplinas, que deve ser acessado a partir das 8:10h do dia 04/12/2025 exclusivamente de um dos computadores do Laboratório LEI-SEL-MENOR;
#
# - Só será permitido o envio da prova resolvida até às 9:10 do mesmo dia, totalizando 60 minutos de duração;
#
# - Após a conclusão da prova, faça o download do Jupyter notebook e envie para o professor pelo sistema E-Disciplinas;
#
# - Provas realizadas com acesso de outro computador não pertencente ao LEI-SEL não serão consideradas;
#
# - As provas são individuais e sem consulta;
#
# - Nenhum outro material deve permanecer com o aluno durante a prova: caderno, livros, notebook, mochila, estojo, calculadora, celular, smartphone, smartwatch, etc. estão proibidos.
#
# - Não será permitido ao aluno portar telefone celular nem smartwatch durante a prova, mesmo que desligado e no bolso. O mesmo deve ser colocado dentro da mochila ou em cima da mesa do professor. Não esqueça de desligá-lo!
#
# - Durante a realização das provas, todos os programas e janelas do computador devem permanecer fechadas, com exceção da tela do navegador com o e-Disciplinas e do Google Colab (exclusivamente no caso da PP2). A consulta a qualquer material online ou qualquer site durante a realização da prova será considerado "cola" e anulará a prova do aluno, que ficará com nota zero.
#
# - O aluno não poderá sair da sala durante o período de cada prova (apenas no intervalo entre elas);
#
# - Os monitores da disciplina não são autorizados a responder nenhuma pergunta sobre o conteúdo das provas.
#
# - Boa Prova!
#
#
# **Dicas gerais:**
#
# * Caso queira obter a descrição de uma função específica, você pode utilizar o comando `help()`. Por exemplo: `help(np.max)`
#
# ---
#
#
#
#  <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/github/LAVI-Disciplinas/SEL0339-SEL5886_2025_PROVA-PRATICA/blob/main/PP2/Prova_Pratica_P2_SEL0339_SEL5886_(2025).ipynb"><img src="https://www.tensorflow.org/images/colab_logo_32px.png" />Executar no Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/LAVI-Disciplinas/SEL0339-SEL5886_2025_PROVA-PRATICA/blob/main/PP2/Prova_Pratica_P2_SEL0339_SEL5886_(2025).ipynb"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />Ver codigo fonte no GitHub</a>
#   </td>
# </table>

# %% [markdown]
# `Nome: `
#
# `Número USP: `

# %% [markdown]
# ## Prova Prática

# %% [markdown]
# Um instituto responsável por mapear áreas de queimadas e desmatamento na Floresta Amazônica utiliza imagens de satélite e um sistema de visão computacional para classificar as regiões. O sistema pré-processa a imagem adquirida e faz recortes em toda a imagem de maneira a classificar cada um deles em três classes: Floresta (Classe 1), Área Desmatada (Classe 2) e Área de Queimada (Classe 3). Na Figura abaixo se tem um exemplo de recorte pertencente à cada classe.

# %% [markdown]
# <center><figure class="half" style="display:flex">
#     <img width="700" src="https://github.com/LAVI-Disciplinas/SEL0339-SEL5886_2025_PROVA-PRATICA/raw/main//PP2/Imagens_prova/recortes_classes.jpeg">
#  </figure>
#     <figcaption><b> Figura 1: </b> Exemplos de recortes pertencentes a cada uma das classes.</figcaption>
# </center>

# %% [markdown]
# Para a classificação de cada recorte foi feita uma análise baseada nas informações de textura. Para tanto, foram extraídas três descritores baseados em medidas estatísticas da matriz de co-ocorrência de tons de cinza (GLCM): energia, homogeneidade e correlação, formando assim um vetor de característica com três atributos. O processo de classificação é supervisionado, de forma que o instituto já tem em sua posse um conjunto de recortes devidamente rotulados (etiquetados).

# %% [markdown]
# Classe 1 -> Floresta
#
# Classe 2 -> Queimada
#
# Classe 3 -> Desmatamento

# %% [markdown]
# #### **Atenção**: os códigos abaixo são para fazer o download e visualização do banco de dados 'dados.csv' a ser usado nesta prova (EXECUTE-OS).

# %%
import urllib.request

try:
  urllib.request.urlretrieve("https://raw.githubusercontent.com/LAVI-Disciplinas/SEL0339-SEL5886_2025_PROVA-PRATICA/refs/heads/main/PP2/dados.csv", "dados.csv")
except:
  print("[ERRO] Não foi possível fazer o download das imagens dessa prática. Entre em contato com o monitor")

# %%
import numpy as np
import pandas as pd
# Carregando o conjunto de dados
data = pd.read_csv('dados.csv',index_col=0)

# %%
data

# %% [markdown]
# ## Exercício 1 - Realize a Normalização
# $$X_{norm}= \frac{X-X_{min}}{X_{max}-X_{min}} $$

# %%
# Ex1: Função de Normalização
def normalize_data(data):
    ## SEU CODIGO AQUI
    return normalized_data

# rodar sem a coluna de classificacao
normalized_data = normalize_data(data[['Energia','Homogeneidade','Correlação']])
normalized_data

# %% [markdown]
# ## Exercício 2 - Realize a Clusterização com o KMeans e o plot dos clusters

# %%
# Passo 3: Clusteriazacao, deverá retornar o cluster_centers_ e o labels
from sklearn.cluster import KMeans
def perform_clustering(data, n_clusters=3):
    ## SEU CODIGO AQUI

# %%
# pegar o centroides e labels
centroids, labels = perform_clustering(normalized_data)
print("Centróides dos clusters:", centroids)
print("Rótulos das amostras:", labels)

# %%
# Certifique-se de que os dados estão no formato NumPy!!!
normalized_data = normalized_data.to_numpy()

# %%
# Função para visualização em 3D (apenas para vizualização não precisa mexer)
import matplotlib.pyplot as plt
def plot_clusters_3d(data, labels, centroids):
    fig = plt.figure(figsize=(10, 8))
    ax = fig.add_subplot(111, projection='3d')

    # Plota os pontos e colore pelos rótulos
    scatter = ax.scatter(data[:, 0], data[:, 1], data[:, 2], c=labels, cmap='viridis', s=50, alpha=0.8)

    # Adiciona os centróides
    ax.scatter(centroids[:, 0], centroids[:, 1], centroids[:, 2], marker='*', s=300, c='red', label='Centroids')

    # Configurações dos eixos
    ax.set_xlabel('Energia')
    ax.set_ylabel('Homogeneidade')
    ax.set_zlabel('Correlação')
    ax.legend()
    plt.colorbar(scatter, ax=ax, label='Cluster Label')
    plt.title('Visualização dos Clusters em 3D')
    plt.show()

# Plotagem dos clusters em 3D
plot_clusters_3d(normalized_data, labels, centroids)

# %% [markdown]
# ## Exercício 3 - Classificação com Árvore de Decisão Simples (Sem Utilizar Normalização)
#
# Você deve implementar um classificador com árvore de decisão, baseado em regras simples para distinguir entre as três classes (Floresta, Queimada e Desmatamento), sem utilizar normalização.

# %%
# Classificação com Árvore de Decisão Simples (SEM UTILIZAR NORMALIZACAO)
def classify_with_tree(data):
    # features do conjunto de dados
    energia, homogeneidade, correlacao = data
    # SUAS REGRAS PARA CLASSIFICACAO, apenas simples if else com base nos descritores.
    # defina as regras e com base nelas retorna a classe (1.0, 2.0, 3.0)

# %% [markdown]
# ### Teste o seu classificador
# Apenas para ter um comparativo e conseguir ir melhorando suas regras.
# Não precisa alterar.

# %%
print("\nClassificação com Árvore de Decisão Simples:")

# Lista para armazenar os erros
erros = []
data_values = data[['Energia', 'Homogeneidade', 'Correlação']].to_numpy()
for i, sample in enumerate(data_values):
    class_label = classify_with_tree(sample[:3])  # Passa apenas Energia, Homogeneidade e Correlação
    classe_real = data.iloc[i]['Classificação']  # Obtém a classe real do DataFrame original

    # Adiciona o erro (0 se correto, 1 se incorreto)
    erros.append(0 if class_label == classe_real else 1)

    # Exibe a classificação
    print(f"Amostra {i+1}: {sample}, Classe pela Árvore: {class_label}, Classe real: {classe_real}")

# Calcula e exibe o erro médio
erro_medio = sum(erros) / len(erros)
print(f"\nErro médio da árvore de decisão: {erro_medio:.2f}")
